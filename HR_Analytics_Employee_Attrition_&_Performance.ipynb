# %% [markdown]
# <a href="https://colab.research.google.com/github/Chan3377/HR-Analytics-Employee-Attrition-Performance/blob/main/HR_Analytics_Employee_Attrition_%26_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HR Analytics Employee Attrition & Performance**

# %% [markdown]
# This analysis is to uncover the factors that lead to employee attrition for company.

# %% [markdown]
# ## **Import Libraries**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import joblib

# %% [markdown]
# ##**Load dataset**

# %%
file_path = "/content/drive/MyDrive/dataset/Employee.csv"
data = pd.read_csv(file_path)
df = data.copy()
# To show all columns
pd.options.display.max_columns = 50
df.shape
# Out:
# (1470, 23)

# %%
performance_file_path = "/content/drive/MyDrive/dataset/PerformanceRating.csv"
data_performance = pd.read_csv(performance_file_path)
df_pr = data_performance.copy()
# To show all columns
pd.options.display.max_columns = 50
df_pr.shape
# Out:
# (6709, 11)

# %%
# prompt: join both dataset by EmployeeID for only available EmployeeID data on df dataset

df_merged = pd.merge(df, df_pr, on='EmployeeID', how='inner')
df_merged.shape
# Out:
# (6709, 33)

# %%
df_merged.groupby('EmployeeID').head(100)
# Out:
#      EmployeeID FirstName LastName  Gender  Age BusinessTravel Department  \
# 0     3012-1A41  Leonelle    Simco  Female   30    Some Travel      Sales
# 1     3012-1A41  Leonelle    Simco  Female   30    Some Travel      Sales
# 2     3012-1A41  Leonelle    Simco  Female   30    Some Travel      Sales
# 3     3012-1A41  Leonelle    Simco  Female   30    Some Travel      Sales
# 4     3012-1A41  Leonelle    Simco  Female   30    Some Travel      Sales
# ...         ...       ...      ...     ...  ...            ...        ...
# 6704  06E8-4FD4    Emilee   Wenham  Female   20    Some Travel      Sales
# 6705  06E8-4FD4    Emilee   Wenham  Female   20    Some Travel      Sales
# 6706  06E8-4FD4    Emilee   Wenham  Female   20    Some Travel      Sales
# 6707  06E8-4FD4    Emilee   Wenham  Female   20    Some Travel      Sales
# 6708  06E8-4FD4    Emilee   Wenham  Female   20    Some Travel      Sales
#
#       DistanceFromHome (KM) State                  Ethnicity  Education  \
# ...

# %%
df_merged.groupby('EmployeeID')['TrainingOpportunitiesWithinYear'].head()
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       1
#        ..
# 6700    1
# 6701    1
# 6702    1
# 6703    3
# 6704    1
# Name: TrainingOpportunitiesWithinYear, Length: 4896, dtype: int64

# %%
# Check : show the FirstName and LastName where EmployeeID equal '005C-E0FB'

df_merged[df_merged['EmployeeID'] == '005C-E0FB']
# Out:
#      EmployeeID FirstName      LastName      Gender  Age      BusinessTravel  \
# 4817  005C-E0FB       Fin  O'Halleghane  Non-Binary   24  Frequent Traveller
# 4818  005C-E0FB       Fin  O'Halleghane  Non-Binary   24  Frequent Traveller
# 4819  005C-E0FB       Fin  O'Halleghane  Non-Binary   24  Frequent Traveller
#
#      Department  DistanceFromHome (KM) State Ethnicity  Education  \
# 4817      Sales                     17    CA     White          4
# 4818      Sales                     17    CA     White          4
# 4819      Sales                     17    CA     White          4
#
#      EducationField          JobRole MaritalStatus  Salary  StockOptionLevel  \
# 4817     Marketing   Sales Executive       Married   56155                 1
# 4818     Marketing   Sales Executive       Married   56155                 1
# 4819     Marketing   Sales Executive       Married   56155                 1
#
#      OverTime    HireDate Attrition  YearsAtCompany  YearsInMostRecentRole  \
# ...
